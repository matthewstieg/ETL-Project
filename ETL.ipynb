# %%
import pandas as pd
import numpy as np

wmp_file = "wiki_movie_plots_deduped.csv"

wmp_data = pd.read_csv(wmp_file, encoding='utf8')
wmp_data.describe()
wmp_data.columns
# Out:
# Index(['Release Year', 'Title', 'Origin/Ethnicity', 'Director', 'Cast',
#        'Genre', 'Wiki Page', 'Plot'],
#       dtype='object')

# %%
wmp_data.drop_duplicates(subset = 'Title', keep = False, inplace = True)

wmp_data = wmp_data[['Release Year', 'Title', 'Director', 'Cast',
       'Genre', 'Wiki Page']]

wmp_data.set_index('Title',inplace=True)
# wmp_data.describe()
wmp_data.head()
# Out:
#                                   Release Year         Director Cast    Genre  \
# Title
# Kansas Saloon Smashers                    1901          Unknown  NaN  unknown
# Love by the Light of the Moon             1901          Unknown  NaN  unknown
# The Martyred Presidents                   1901          Unknown  NaN  unknown
# Terrible Teddy, the Grizzly King          1901          Unknown  NaN  unknown
# The Great Train Robbery                   1903  Edwin S. Porter  NaN  western
#
#                                                                           Wiki Page
# Title
# Kansas Saloon Smashers            https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# Love by the Light of the Moon     https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# The Martyred Presidents           https://en.wikipedia.org/wiki/The_Martyred_Pre...
# Terrible Teddy, the Grizzly King  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# The Great Train Robbery           https://en.wikipedia.org/wiki/The_Great_Train_...

# %%
imdb_file = "IMDB-Movie-Data.csv"

imdb_data = pd.read_csv(imdb_file)
imdb_data.describe()
imdb_data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
imdb_data.drop_duplicates(subset = 'Title', keep = False, inplace = True)

imdb_data = imdb_data[['Title', 'Rating']]

imdb_data.set_index('Title',inplace=True)

# imdb_data.describe()
imdb_data.head()
# Out:
#                          Rating
# Title
# Guardians of the Galaxy     8.1
# Prometheus                  7.0
# Split                       7.3
# Sing                        7.2
# Suicide Squad               6.2

# %%
tmdb_file = "tmdb_5000_movies.csv"

tmdb_data = pd.read_csv(tmdb_file)
tmdb_data.describe()
tmdb_data.columns
# unique_lang = tmdb_data['original_language'].nunique()
# ul_df = pd.DataFrame({"Total Languages": [unique_lang]})
# ul_df.head()
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
tmdb_data.drop_duplicates(subset = 'original_title', keep = False, inplace = True)
tmdb_data.rename(columns={'title': 'Title'}, inplace=True)

tmdb_data = tmdb_data[['budget', 'homepage', 'original_language',
       'runtime', 'tagline', 'Title',]]

tmdb_data.set_index('Title',inplace=True)

# tmdb_data.describe()
tmdb_data.head()
# Out:
#                                              budget  \
# Title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
#
#                                                                               homepage  \
# Title
# Avatar                                                     http://www.avatarmovie.com/
# Pirates of the Caribbean: At World's End  http://disney.go.com/disneypictures/pirates/
# Spectre                                    http://www.sonypictures.com/movies/spectre/
# The Dark Knight Rises                               http://www.thedarkknightrises.com/
# John Carter                                       http://movies.disney.com/john-carter
#
#                                          original_language  runtime  \
# Title
# Avatar                                                  en    162.0
# Pirates of the Caribbean: At World's End                en    169.0
# Spectre                                                 en    148.0
# The Dark Knight Rises                                   en    165.0
# John Carter                                             en    132.0
#
#                                                                                  tagline
# Title
# Avatar                                                       Enter the World of Pandora.
# Pirates of the Caribbean: At World's End  At the end of the world, the adventure begins.
# Spectre                                                            A Plan No One Escapes
# The Dark Knight Rises                                                    The Legend Ends
# John Carter                                         Lost in our world, found in another.

# %%
imdb_tmdb_merged = pd.merge(tmdb_data, imdb_data, on='Title', how='left')

# imdb_tmdb_merged.head()
imdb_tmdb_merged.describe()
# Out:
#              budget      runtime      Rating
# count  4.799000e+03  4797.000000  627.000000
# mean   2.906167e+07   106.875756    6.809888
# std    4.073299e+07    22.618827    0.878059
# min    0.000000e+00     0.000000    1.900000
# 25%    8.000000e+05    94.000000    6.300000
# 50%    1.500000e+07   103.000000    6.800000
# 75%    4.000000e+07   118.000000    7.500000
# max    3.800000e+08   338.000000    9.000000

# %%
all_three_merged = pd.merge(wmp_data, imdb_tmdb_merged, on='Title')

all_three_merged.head(50)
# all_three_merged.describe()
# Out:
#                                  Release Year             Director  \
# Title
# The Immigrant                            1917      Charles Chaplin
# The Big Parade                           1925           King Vidor
# The Broadway Melody                      1929       Harry Beaumont
# Hell's Angels                            1930        Howard Hughes
# 42nd Street                              1933          Lloyd Bacon
# She Done Him Wrong                       1933       Lowell Sherman
# It Happened One Night                    1934          Frank Capra
# The Painted Veil                         1934  Richard Boleslawski
# Top Hat                                  1935        Mark Sandrich
# High Tension                             1936           Allan Dwan
# Modern Times                             1936      Charles Chaplin
# Snow White and the Seven Dwarfs          1937           David Hand
# Gone with the Wind                       1939       Victor Fleming
# Mr. Smith Goes to Washington             1939          Frank Capra
# The Wizard of Oz                         1939       Victor Fleming
# Wuthering Heights                        1939        William Wyler
# Boom Town                                1940          Jack Conway
# Rebecca                                  1940     Alfred Hitchcock
# How Green Was My Valley                  1941            John Ford
# Bambi                                    1942           David Hand
# Casablanca                               1942       Michael Curtiz
# A Guy Named Joe                          1943       Victor Fleming
# Bathing Beauty                           1944        George Sidney
# The Bridge of San Luis Rey               1944       Rowland V. Lee
# Summer Storm                             1944         Douglas Sirk
# The Lost Weekend                         1945         Billy Wilder
# State Fair                               1945          Walter Lang
# The Best Years of Our Lives              1946        William Wyler
# Duel in the Sun                          1946           King Vidor
# Inside Job                               1946       Jean Yarbrough
# Christmas Eve                            1947       Edwin L. Marin
# Gentleman's Agreement                    1947           Elia Kazan
# The Lady from Shanghai                   1947         Orson Welles
# The Secret Life of Walter Mitty          1947     Norman Z. McLeod
# Open Secret                              1948       John Reinhardt
# The Pirate                               1948    Vincente Minnelli
# Abandoned                                1949     Joseph M. Newman
# Sands of Iwo Jima                        1949           Allan Dwan
# She Wore a Yellow Ribbon                 1949            John Ford
# Quo Vadis                                1951         Mervyn LeRoy
# A Streetcar Named Desire                 1951           Elia Kazan
# Casablanca                         878000
# A Guy Named Joe                   2627000
# Bathing Beauty                    2361000
# The Bridge of San Luis Rey              0
# Summer Storm                      2700000
# The Lost Weekend                  1250000
# State Fair                              0
# The Best Years of Our Lives       2100000
# Duel in the Sun                   6000000
# Inside Job                        2000000
# Christmas Eve                           0
# Gentleman's Agreement             2000000
# The Lady from Shanghai            2300000
# The Secret Life of Walter Mitty  90000000
# Open Secret                             0
# The Pirate                        3700000
# Abandoned                               0
# Sands of Iwo Jima                 1000000
# She Wore a Yellow Ribbon          1600000
# Quo Vadis                         8250000
# A Streetcar Named Desire          1800000
# The Greatest Show on Earth        4000000
# High Noon                          730000
# Singin' in the Rain               2540800
# Thunderbirds                     57000000
# The Beast from 20,000 Fathoms      210000
# From Here to Eternity             1650000
# Niagara                           1250000
# The Robe                          4100000
# The Egyptian                      5000000
#
#                                                                           homepage  \
# Title
# The Immigrant                                      http://theimmigrant-lefilm.com/
# The Big Parade                                                                 NaN
# The Broadway Melody                                                            NaN
# Hell's Angels                                                                  NaN
# 42nd Street                                                                    NaN
# She Done Him Wrong                                                             NaN
# It Happened One Night                                                          NaN
# The Painted Veil                                                               NaN
# Top Hat                                                                        NaN
# High Tension                                                                   NaN
# Modern Times                                                                   NaN
# Snow White and the Seven Dwarfs  http://movies.disney.com/snow-white-and-the-se...
# Gone with the Wind                                                             NaN
# Mr. Smith Goes to Washington                                                   NaN
# The Wizard of Oz                              http://thewizardofoz.warnerbros.com/
# Wuthering Heights                http://www.pbs.org/wgbh/masterpiece/wutheringh...
# Boom Town                                                                      NaN
# Rebecca                                                                        NaN
# How Green Was My Valley                                                        NaN
# Bambi                                               http://movies.disney.com/bambi
# Casablanca                                                                     NaN
# A Guy Named Joe                                                                NaN
# Bathing Beauty                                                                 NaN
# The Bridge of San Luis Rey              http://www.thebridgeofsanluisreymovie.com/
# Summer Storm                                   http://www.sommersturm.de/main.html
# The Lost Weekend                                                               NaN
# State Fair                                                                     NaN
# The Best Years of Our Lives                                                    NaN
# Duel in the Sun                                                                NaN
# Inside Job                                  http://www.sonyclassics.com/insidejob/
# Christmas Eve                                   http://www.thestuckmovie.com/#menu
# Gentleman's Agreement                                                          NaN
# The Lady from Shanghai                                                         NaN
# The Secret Life of Walter Mitty                                                NaN
# Open Secret                                                                    NaN
# The Pirate                                                                     NaN
# Abandoned                                                                      NaN
# Sands of Iwo Jima                                                              NaN
# She Wore a Yellow Ribbon                                                       NaN
# Quo Vadis                                                                      NaN
# A Streetcar Named Desire                                                       NaN
# The Greatest Show on Earth                                                     NaN
# High Noon                                                                      NaN
# Singin' in the Rain                                                            NaN
# Thunderbirds                                      http://www.thunderbirdsmovie.com
# The Beast from 20,000 Fathoms                                                  NaN
# From Here to Eternity                                                          NaN
# Niagara                                                                        NaN
# The Robe                                                                       NaN
# The Egyptian                                                                   NaN
#
#                                 original_language  runtime  \
# Title
# The Immigrant                                  en    117.0
# The Big Parade                                 en    151.0
# The Broadway Melody                            en    100.0
# Hell's Angels                                  en    127.0
# 42nd Street                                    en     89.0
# She Done Him Wrong                             en     66.0
# It Happened One Night                          en    105.0
# The Painted Veil                               en    125.0
# Top Hat                                        en    101.0
# High Tension                                   fr     91.0
# Modern Times                                   en     87.0
# Snow White and the Seven Dwarfs                en     83.0
# Gone with the Wind                             en    238.0
# Mr. Smith Goes to Washington                   en    129.0
# The Wizard of Oz                               en    102.0
# Wuthering Heights                              en    142.0
# Boom Town                                      en    119.0
# Rebecca                                        en    130.0
# How Green Was My Valley                        en    118.0
# Bambi                                          en     70.0
# Casablanca                                     en    102.0
# A Guy Named Joe                                en    120.0
# Bathing Beauty                                 en    101.0
# The Bridge of San Luis Rey                     en    120.0
# Summer Storm                                   de     98.0
# The Lost Weekend                               en    101.0
# State Fair                                     en     96.0
# The Best Years of Our Lives                    en    172.0
# Duel in the Sun                                en    144.0
# Inside Job                                     en    109.0
# Christmas Eve                                  en     95.0
# Gentleman's Agreement                          en    118.0
# The Lady from Shanghai                         en     87.0
# The Secret Life of Walter Mitty                en    114.0
# Open Secret                                    en     68.0
# The Pirate                                     en    102.0
# Abandoned                                      en     82.0
# Sands of Iwo Jima                              en    100.0
# She Wore a Yellow Ribbon                       en    103.0
# Quo Vadis                                      en    171.0
# A Streetcar Named Desire                       en    125.0
# The Greatest Show on Earth                     en    152.0
# High Noon                                      en     85.0
# Singin' in the Rain                            en    103.0
# Thunderbirds                                   en     95.0
# The Beast from 20,000 Fathoms                  en     80.0
# From Here to Eternity                          en    118.0
# Niagara                                        en     92.0
# The Robe                                       en    135.0
# The Egyptian                                   en    139.0
#
#                                                                            tagline  \
# Title
# The Immigrant                                                                  NaN
# The Big Parade                                                                 NaN
# The Broadway Melody              The pulsating drama of Broadway's bared heart ...
# Hell's Angels                    Howard Hughes' Thrilling Multi-Million Dollar ...
# 42nd Street                                                                    NaN
# She Done Him Wrong                      Mae West gives a 'Hot Time' to the nation!
# It Happened One Night                               TOGETHER... for the first time
# The Painted Veil                 Sometimes the greatest journey is the distance...
# Top Hat                                      They're Dancing Cheek-To-Cheek Again!
# High Tension                                                    Hearts will bleed.
# Modern Times                     He stands alone as the greatest entertainer of...
# Snow White and the Seven Dwarfs  The Happiest, Dopiest, Grumpiest, Sneeziest mo...
# Gone with the Wind                               The greatest romance of all time!
# Mr. Smith Goes to Washington     Romance, drama, laughter and heartbreak... cre...
# The Wizard of Oz                 We're off to see the Wizard, the wonderful Wiz...
# Wuthering Heights                                                              NaN
# Boom Town                        Where Men Are Rough And Tough . . . And Like T...
# Rebecca                              The shadow of this woman darkened their love.
# How Green Was My Valley          Millions Have Read This Great Novel... Million...
# Bambi                                                          A great love story.
# Casablanca                                They had a date with fate in Casablanca!
# A Guy Named Joe                                A GUY - A GAL - A PAL - It's Swell!
# Bathing Beauty                      M.G.M's Mammoth Technicolor Musical Spectacle!
# The Bridge of San Luis Rey                                                     NaN
# Summer Storm                                                                   NaN
# The Lost Weekend                 The screen dares to open the strange and savag...
# State Fair                                                                     NaN
# The Best Years of Our Lives      Three wonderful loves in the best picture of t...
# Duel in the Sun                  Emotions . . . As Violent As The Wind-Swept Pr...
# Inside Job                         The film that cost $20,000,000,000,000 to make.
# Christmas Eve                    They'll be home for Christmas...if only in the...
# Gentleman's Agreement                                                          NaN
# The Lady from Shanghai             I told you... you know nothing about wickedness
# The Secret Life of Walter Mitty                        Stop Dreaming, Start Living
# Open Secret                      The Pull-No-Punch drama of men chained togethe...
# The Pirate                                           The great MGM musical romance
# Abandoned                                                                      NaN
# Sands of Iwo Jima                A Great Human Story... Makes A Mighty Motion P...
# She Wore a Yellow Ribbon         John Ford's New and Finest Picture of the Figh...
# Quo Vadis                        THIS IS THE BIG ONE! The splendor and savagery...
# A Streetcar Named Desire          ...Blanche, who wanted so much to stay a lady...
# The Greatest Show on Earth                                                     NaN
# High Noon                             The story of a man who was too proud to run.
# Singin' in the Rain                                       What a Glorious Feeling!
# Thunderbirds                                                                   NaN
# The Beast from 20,000 Fathoms                                         It's alive !
# From Here to Eternity            Pouring out of impassioned pages...brawling th...
# Niagara                          A raging torrent of emotion that even nature c...
# The Robe                         The first motion picture in CinemaScope--the m...
# The Egyptian                     To Nefer, shameless temptress of Babylon, he s...
#
#                                  Rating
# Title
# The Immigrant                       NaN
# The Big Parade                      NaN
# The Broadway Melody                 NaN
# Hell's Angels                       NaN
# 42nd Street                         NaN
# She Done Him Wrong                  NaN
# It Happened One Night               NaN
# The Painted Veil                    NaN
# Top Hat                             NaN
# High Tension                        NaN
# Modern Times                        NaN
# Snow White and the Seven Dwarfs     NaN
# Gone with the Wind                  NaN
# Mr. Smith Goes to Washington        NaN
# The Wizard of Oz                    NaN
# Wuthering Heights                   NaN
# Boom Town                           NaN
# Rebecca                             NaN
# How Green Was My Valley             NaN
# Bambi                               NaN
# Casablanca                          NaN
# A Guy Named Joe                     NaN
# Bathing Beauty                      NaN
# The Bridge of San Luis Rey          NaN
# Summer Storm                        NaN
# The Lost Weekend                    NaN
# State Fair                          NaN
# The Best Years of Our Lives         NaN
# Duel in the Sun                     NaN
# Inside Job                          NaN
# Christmas Eve                       NaN
# Gentleman's Agreement               NaN
# The Lady from Shanghai              NaN
# The Secret Life of Walter Mitty     7.3
# Open Secret                         NaN
# The Pirate                          NaN
# Abandoned                           NaN
# Sands of Iwo Jima                   NaN
# She Wore a Yellow Ribbon            NaN
# Quo Vadis                           NaN
# A Streetcar Named Desire            NaN
# The Greatest Show on Earth          NaN
# High Noon                           NaN
# Singin' in the Rain                 NaN
# Thunderbirds                        NaN
# The Beast from 20,000 Fathoms       NaN
# From Here to Eternity               NaN
# Niagara                             NaN
# The Robe                            NaN
# The Egyptian                        NaN

# %%
# reset index
all_three_merged.reset_index(inplace=True)
# make id column
all_three_merged.insert(0, 'ID', range(1, 1 + len(all_three_merged)))
# reassign index on id
all_three_merged.set_index('ID',inplace=True)

# %%
all_three_merged.describe()
# Out:
#        Release Year        budget      runtime      Rating
# count   3056.000000  3.056000e+03  3056.000000  421.000000
# mean    2000.544175  3.368453e+07   108.806283    6.831829
# std       13.293465  4.174988e+07    20.426575    0.876945
# min     1917.000000  0.000000e+00     0.000000    1.900000
# 25%     1997.000000  4.000000e+06    95.000000    6.300000
# 50%     2003.000000  2.000000e+07   105.000000    6.900000
# 75%     2009.000000  4.700000e+07   119.000000    7.500000
# max     2017.000000  3.000000e+08   276.000000    9.000000

# %%
# export file
all_three_merged.to_excel("all_three_merged.xlsx")

# %%
import pymongo
import json

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
# Declare the database
db = client.movies_db

# Declare the collection
collection = db.info_db

info = db.info.find()

collection.insert_many(all_three_merged.to_dict('records'))
